# %%
l = []
for i in open("ascii.txt"):
    l.append(i.split(",")[1])

# %%
s = []
for i in open("ascii.txt"):
    s.append(i.split(",")[1])

# %%
t = []
for i in l:
    t.append(i[0].split("'\\'"))

# %%
l = []
for i in open("ascii.csv").readlines()[1:]:
    l.append(i)

# %%
[x.split(",")[1].strip("'\\'") for x in l]
# Out:
# ['xBD',
#  'x84',
#  '7',
#  'x9C',
#  'xF9',
#  'o',
#  'H',
#  'xEE',
#  'x04',
#  '4',
#  'C',
#  '!',
#  'Y',
#  ' ',
#  'xF9',
#  'xA4',
#  '~',
#  '(',
#  'xB6',
#  't',
#  'x84',
#  'I',
#  'C',
#  'xE6',
#  'xA4',
#  'xDD',
#  'Y',
#  'xAD',
#  'xB4',
#  'xA0',
#  'o',
#  'xC0',
#  '>',
#  ' ',
#  'x07',
#  'n',
#  'x10',
#  'xDD',
#  'x86',
#  'C',
#  'xBF',
#  '`',
#  'xD9',
#  'x90',
#  'n',
#  'xF6',
#  '4',
#  'xF9',
#  'xA4',
#  'x01',
#  'xBE',
#  'x14',
#  'xF9',
#  'Y',
#  'xAD',
#  'xB4',
#  'xA0',
#  'o',
#  'xC0',
#  '>',
#  'xA4',
#  'x03',
#  'C',
#  ' ',
#  'xA4',
#  'n',
#  'o',
#  ' ',
#  'xD9',
#  'A',
#  'x01',
#  'g',
#  ' ',
#  '$',
#  'C',
#  'x88',
#  '+',
#  'B',
#  'xA4',
#  'x16',
#  'xC9',
#  '4',
#  't',
#  '>',
#  'x1C',
#  'x96',
#  'xED',
#  'J',
#  'xBF',
#  'xB4',
#  '0',
#  '~',
#  'x10',
#  'xDD',
#  'B',
#  'x08',
#  'xAE',
#  ' ',
#  'x02',
#  'I',
#  'f',
#  'x14',
#  'x08',
#  'xB4',
#  'x0B',
#  'xB7',
#  'L',
#  'O',
#  'x84',
#  '7',
# ...

# %%
s = []
for i in [x[0] for x in [x.split(",")[1].strip("'\\'") for x in l]]:
    s.append(i)

# %%
st = ""
print(st.join(s))
# Out:
# xx7xxoHxx4C!Y xx~(xtxICxxxYxxxox> xnxxxCx`xxnx4xxxxxxYxxxox>xxC xno xAxg $Cx+Bxxx4t>xxxJxx0~xxBxx xIfxxxxxLOx7xxo@0xxxdxBxxx6x&0xx+xtxx xxx>xxC xno xAxg $Cx+Bxxx4t>xxxKx 4xxxxxxx04Bx@xxJx|xixx]xxxxx02xxxx$xxxx4@x`n4t>xxx/xxxx4J4x xx0x4x5xxLOx7xxo@xKB%xKxxKgxxKx xxx4xY xxx>xCx xx?xxK"x5x@6xnx6xkt>xxxB4xxIx426xx C0xxxxxxx4t>xxxB4xxIx426xx C0xxxxxxx4t>xxmxDxxxxxx]Nxu!x6xxxxxxtM

# %%
s
# Out:
# ['x',
#  'x',
#  '7',
#  'x',
#  'x',
#  'o',
#  'H',
#  'x',
#  'x',
#  '4',
#  'C',
#  '!',
#  'Y',
#  ' ',
#  'x',
#  'x',
#  '~',
#  '(',
#  'x',
#  't',
#  'x',
#  'I',
#  'C',
#  'x',
#  'x',
#  'x',
#  'Y',
#  'x',
#  'x',
#  'x',
#  'o',
#  'x',
#  '>',
#  ' ',
#  'x',
#  'n',
#  'x',
#  'x',
#  'x',
#  'C',
#  'x',
#  '`',
#  'x',
#  'x',
#  'n',
#  'x',
#  '4',
#  'x',
#  'x',
#  'x',
#  'x',
#  'x',
#  'x',
#  'Y',
#  'x',
#  'x',
#  'x',
#  'o',
#  'x',
#  '>',
#  'x',
#  'x',
#  'C',
#  ' ',
#  'x',
#  'n',
#  'o',
#  ' ',
#  'x',
#  'A',
#  'x',
#  'g',
#  ' ',
#  '$',
#  'C',
#  'x',
#  '+',
#  'B',
#  'x',
#  'x',
#  'x',
#  '4',
#  't',
#  '>',
#  'x',
#  'x',
#  'x',
#  'J',
#  'x',
#  'x',
#  '0',
#  '~',
#  'x',
#  'x',
#  'B',
#  'x',
#  'x',
#  ' ',
#  'x',
#  'I',
#  'f',
#  'x',
#  'x',
#  'x',
#  'x',
#  'x',
#  'L',
#  'O',
#  'x',
#  '7',
#  'x',
#  'x',
#  'o',
#  '@',
#  '0',
#  'x',
#  'x',
#  'x',
#  'd',
#  'x',
#  'B',
#  'x',
#  'x',
#  'x',
#  '6',
# ...

# %%
ls
# Out:
# ascii.txt  flag.txt  hex.txt  lab3.ipynb  OffensiveSicherheitsmethoden_lab3.pdf

# %%
for i in open("ascii.csv"):
    print("".join(i.split(",")[1]))
# Out:
# Value
# \xBD
# \x84
# 7
# \x9C
# \xF9
# o
# H
# \xEE
# \x04
# 4
# C
# !
# Y
#
# \xF9
# \xA4
# ~
# (
# \xB6
# \t
# \x84
# I
# C
# \xE6
# \xA4
# \xDD
# Y
# \xAD
# \xB4
# \xA0
# o
# \xC0
# >
#
# \x07
# \n
# \x10
# \xDD
# \x86
# C
# \xBF
# `
# \xD9
# \x90
# \n
# \xF6
# 4
# \xF9
# \xA4
# \x01
# \xBE
# \x14
# \xF9
# Y
# \xAD
# \xB4
# \xA0
# o
# \xC0
# >
# \xA4
# \x03
# C
#
# \xA4
# \n
# o
#
# \xD9
# A
# \x01
# g
#
# $
# C
# \x88
# +
# B
# \xA4
# \x16
# \xC9
# 4
# \t
# >
# \x1C
# \x96
# \xED
# J
# \xBF
# \xB4
# \0
# ~
# \x10
# \xDD
# B
# \x08
# \xAE
#
# \x02
# I
# f
# \x14
# \x08
# \xB4
# \x0B
# \xB7
# L
# O
# \x84
# 7
# \x9C
# \xF9
# o
# @
# 0
# \xD9
# \x10
# \xEF
# d
# \x08
# B
# \x10
# \x0B
# \x86
# 6
# \x04
# &
# \0
# \xB6
# \x84
# +
# \x90
# \t
# \xE9
# \xB0
#
# \xE6
# \xF1
# \xC0
# >
# \xA4
# \x03
# C
#
# \xA4
# \n
# o
#
# \xD9
# A
# \x01
# g
#
# $
# C
# \x88
# +
# B
# \xA4
# \x16
# \xC9
# 4
# \t
# >
# \x1C
# \x96
# \xED
# K
# \xF7
#
# 4
# \xB6
# \x84
# \x82
# \xB7
# \x94
# \x08
# ...
