# %%
l = []
flag = ""
for i in open("ascii.csv").readlines()[2:]:
    l.append(i.split(",")[3].strip("\n")[1])
flag.join(l)
# Out:
# 'MSG] Activity from: ec1c7e7449341b58478c93c27ea6e08a53cc834279e1643dbba994a0e7f3ea43\\\\[MSG] Activity from: 003b9434a45f0eecd2d35bcc78129aa3edc363f802ae5abdd161c4f421ca49a7\\\\[MSG] Activity from: 65ec312325f43f40107dfcba651cab2d1afb6df54578065f1d8bba89801d3ef2\\\\[MSG] Activity from: 223e634cea203ba2c7d4e7931a2dafdf0d452309c1a1eb1a28fc2fae057df400\\\\[MSG] Activity from: 431d591c6eed3b6e793b316d7bf6ce2e3be51aa707680b6f14511fbc9dae9e32\\\\[MSG] Activity from: 65ec312325f43f40107dfcba651cab2d1afb6df54578065f1d8bba89801d3ef2\\\\[MSG] Activity from: 65ec312325f43f40107dfcba651cab2d1afb6df54578065f1d8bba89801d3ef2\\\\[MSG] Activity from: ebb2b5d1dfbbb8174f5fb1fd15230540aea77772d3a65482def3d978f6caf152\\\\[MSG] Activity from: f7fab4b591754a190be32cb607f257f436fa3f325d71edf41b6179c5330cd75a\\\\[MSG] Activity from: 476bdcaf166385371f49c54ba74d275cfdfa5c70c255ea45363e3795cbc11ae5\\\\[MSG] Activity from: 63681fa3c03451c49f9fc2ab9be43bea7f069069c1c472f6a41e3ef3a761de50\\\\[MSG] Activity from
# ...

# %% [markdown]
# **3.3**

# %%
def password_check(user_input):
    password = "secretpass"
    if(len(user_input) == len(password)):
        for idx, element in enumerate(password):
            if(user_input[idx] != element):
                return False
    else:
        return False
    return True

# %%
import time

# %%
import time
def guesslen():
    alph = "abcdefghijklmnopqrstuvwxyz"
    l = {}
    for j in range(len(alph)):
        time0 = time.perf_counter_ns()
        password_check("A"*j)
        time1 = time.thread_time_ns()
        times = time1-time0
        l[j]=times
    l.pop(0)
    pwlen = [x for x,j in l.items() if j==max(l.values())]

    print("The predicted passwort length is:",pwlen)

# %%
guesslen()
# Out:
# The predicted passwort length is: [10]

# %%
import time
chars = "abcdefghijklmnopqrstuvwxyz"
s = ["A"]*10
l = []
find = {}
for i in range(10):
    for j in chars:
        s[i] = j
        find[j]=[]
        for tries in range(1000):
            t0 = time.perf_counter_ns()
            password_check("".join(s[i]))
            t1 = time.perf_counter_ns()
            times = t1-t0
            find[j].append(times)
        find[j]=(sum(find[j]))
    pw = [x for x,j in find.items() if j==max(find.values())]
    print(pw)
# Out:
# ['a']
# ['g']
# ['h']
# ['i']
# ['j']
# ['h']
# ['h']
# ['v']
# ['h']
# ['h']

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
t = np.load("basicpw.sec", allow_pickle=True).item()

# %%
t
# Out:
# {0: (array([ 0.05175781, -0.1015625 , -0.08203125, ..., -0.1953125 ,
#          -0.15527344, -0.11035156]),
#   {0: ('a\n',
#     array([ 0.05761719, -0.10058594, -0.07910156, ..., -0.15527344,
#            -0.10742188, -0.08789062])),
#    1: ('b\n',
#     array([ 0.05566406, -0.1015625 , -0.07910156, ..., -0.1953125 ,
#            -0.15039062, -0.10742188])),
#    2: ('c\n',
#     array([ 0.05859375, -0.109375  , -0.08496094, ..., -0.21484375,
#            -0.16210938, -0.11621094])),
#    3: ('d\n',
#     array([ 0.05957031, -0.10644531, -0.08203125, ..., -0.20703125,
#            -0.15722656, -0.11132812])),
#    4: ('e\n',
#     array([ 0.05761719, -0.10449219, -0.08105469, ..., -0.20996094,
#            -0.15625   , -0.11132812])),
#    5: ('f\n',
#     array([ 0.0625    , -0.109375  , -0.08105469, ..., -0.20898438,
#            -0.15429688, -0.109375  ])),
#    6: ('g\n',
#     array([ 0.05957031, -0.10644531, -0.08203125, ..., -0.20605469,
# ...

# %%
plt.plot(x)
plt.plot(y)
plt.plot(z)

# %%
plt.plot(x)

# %%
x
# Out:
# array([0.        , 0.00195312, 0.00097656, ..., 0.00390625, 0.00097656,
#        0.        ])

# %%
l = []
l2 = []
for j in range(len(t)):
    for i in range(36):
        l.append(np.max(np.abs(t[1][0]-t[0][1][i][1])))

# %%
l = []
l2 = []
for j in range(len(t)):
    for i in range(36):
        l.append(np.max(np.abs(t[j][0]-t[0][1][i][1])))
        l2.append(np.argmax(l))

# %%
z = []
for i in range(36):
    z.append(np.max(np.abs(t[1][0]-t[0][1][i][1])))

# %%
max(z)
# Out:
# 0.361328125

# %%
np.argmax(z)
# Out:
# 32

# %%
t[0][1][1][]
# Out:
#   File "/tmp/ipykernel_94919/3050731773.py", line 1
#     t[0][1][1][]
#                ^
# SyntaxError: invalid syntax

# %%
t[1][0]
# Out:
# array([ 0.05957031, -0.10742188, -0.08203125, ..., -0.16210938,
#        -0.11328125, -0.09277344])

# %%
r = []
for i in range(36):
    r.append(np.max(np.abs(t[1][0]-t[0][1][i][1])))

# %%
r
# Out:
# [0.0576171875,
#  0.3525390625,
#  0.3603515625,
#  0.35546875,
#  0.3564453125,
#  0.3583984375,
#  0.3564453125,
#  0.3564453125,
#  0.357421875,
#  0.3603515625,
#  0.353515625,
#  0.35546875,
#  0.359375,
#  0.3564453125,
#  0.3544921875,
#  0.3583984375,
#  0.35546875,
#  0.3564453125,
#  0.35546875,
#  0.3583984375,
#  0.3564453125,
#  0.357421875,
#  0.35546875,
#  0.359375,
#  0.353515625,
#  0.359375,
#  0.359375,
#  0.3564453125,
#  0.3583984375,
#  0.359375,
#  0.35546875,
#  0.357421875,
#  0.361328125,
#  0.35546875,
#  0.3564453125,
#  0.357421875]

# %%
s = []
for i in range(36):
    s.append(np.max(np.abs(t[1][0]-t[0][1][i][1])))

# %%
max(s)
# Out:
# 0.361328125

# %%
0.361328125 in t
# Out:
# False

# %%
t[1][0]
# Out:
# array([ 0.05957031, -0.10742188, -0.08203125, ..., -0.16210938,
#        -0.11328125, -0.09277344])

# %%
t[0][1][0][1]
# Out:
# array([ 0.05761719, -0.10058594, -0.07910156, ..., -0.15527344,
#        -0.10742188, -0.08789062])

# %%
t[0][1][2][1]
# Out:
# array([ 0.05859375, -0.109375  , -0.08496094, ..., -0.21484375,
#        -0.16210938, -0.11621094])

# %%
t
# Out:
# {0: (array([ 0.05175781, -0.1015625 , -0.08203125, ..., -0.1953125 ,
#          -0.15527344, -0.11035156]),
#   {0: ('a\n',
#     array([ 0.05761719, -0.10058594, -0.07910156, ..., -0.15527344,
#            -0.10742188, -0.08789062])),
#    1: ('b\n',
#     array([ 0.05566406, -0.1015625 , -0.07910156, ..., -0.1953125 ,
#            -0.15039062, -0.10742188])),
#    2: ('c\n',
#     array([ 0.05859375, -0.109375  , -0.08496094, ..., -0.21484375,
#            -0.16210938, -0.11621094])),
#    3: ('d\n',
#     array([ 0.05957031, -0.10644531, -0.08203125, ..., -0.20703125,
#            -0.15722656, -0.11132812])),
#    4: ('e\n',
#     array([ 0.05761719, -0.10449219, -0.08105469, ..., -0.20996094,
#            -0.15625   , -0.11132812])),
#    5: ('f\n',
#     array([ 0.0625    , -0.109375  , -0.08105469, ..., -0.20898438,
#            -0.15429688, -0.109375  ])),
#    6: ('g\n',
#     array([ 0.05957031, -0.10644531, -0.08203125, ..., -0.20605469,
# ...

# %%
np.max(l)
# Out:
# 0.361328125

# %%
np.argmax(l)
# Out:
# 32

# %%
l
# Out:
# [0.009765625,
#  0.009765625,
#  0.009765625,
#  0.009765625,
#  0.0107421875,
#  0.0107421875,
#  0.009765625,
#  0.009765625,
#  0.0087890625,
#  0.0087890625,
#  0.0087890625,
#  0.0087890625,
#  0.01171875,
#  0.01171875,
#  0.009765625,
#  0.009765625,
#  0.0087890625,
#  0.0087890625,
#  0.0087890625,
#  0.0087890625,
#  0.0087890625,
#  0.0087890625,
#  0.0087890625,
#  0.0087890625,
#  0.0087890625,
#  0.0087890625,
#  0.0087890625,
#  0.0087890625,
#  0.009765625,
#  0.009765625,
#  0.0087890625,
#  0.0087890625,
#  0.01171875,
#  0.01171875,
#  0.0107421875,
#  0.0107421875,
#  0.013671875,
#  0.013671875,
#  0.0107421875,
#  0.0107421875,
#  0.0107421875,
#  0.0107421875,
#  0.0107421875,
#  0.0107421875,
#  0.0087890625,
#  0.0087890625,
#  0.01171875,
#  0.01171875,
#  0.0107421875,
#  0.0107421875,
#  0.009765625,
#  0.009765625,
#  0.0498046875,
#  0.0498046875,
#  0.05078125,
#  0.05078125,
#  0.0546875,
#  0.0546875,
#  0.3583984375,
#  0.3583984375,
#  0.01171875,
# ...

# %%
for i in range(len(t)):
    x = np.abs(t[14][0]-t[0][1][0][1])
    y = np.abs(t[14][0]-t[14][1][1][1])
    z = np.abs(t[14][0]-t[14][1][2][1])

# %%
t[0][1][1]
# Out:
# ('b\n',
#  array([ 0.05566406, -0.1015625 , -0.07910156, ..., -0.1953125 ,
#         -0.15039062, -0.10742188]))

# %%
t
# Out:
# {0: (array([ 0.05175781, -0.1015625 , -0.08203125, ..., -0.1953125 ,
#          -0.15527344, -0.11035156]),
#   {0: ('a\n',
#     array([ 0.05761719, -0.10058594, -0.07910156, ..., -0.15527344,
#            -0.10742188, -0.08789062])),
#    1: ('b\n',
#     array([ 0.05566406, -0.1015625 , -0.07910156, ..., -0.1953125 ,
#            -0.15039062, -0.10742188])),
#    2: ('c\n',
#     array([ 0.05859375, -0.109375  , -0.08496094, ..., -0.21484375,
#            -0.16210938, -0.11621094])),
#    3: ('d\n',
#     array([ 0.05957031, -0.10644531, -0.08203125, ..., -0.20703125,
#            -0.15722656, -0.11132812])),
#    4: ('e\n',
#     array([ 0.05761719, -0.10449219, -0.08105469, ..., -0.20996094,
#            -0.15625   , -0.11132812])),
#    5: ('f\n',
#     array([ 0.0625    , -0.109375  , -0.08105469, ..., -0.20898438,
#            -0.15429688, -0.109375  ])),
#    6: ('g\n',
#     array([ 0.05957031, -0.10644531, -0.08203125, ..., -0.20605469,
# ...

# %%
r = []
for i in range(len(t)):
    r.append(np.mean(list(map(lambda x: x[1], t[i][1].values()))))

# %%
z = []
for i in range(36):
    z.append(np.max(np.abs(t[0][0]-t[0][1][i][1])))

# %%
t = np.load("basicpw.sec", allow_pickle=True).item()

# %%
x = []
for i in t.items():
    x.append(i)

# %%
t = np.load("basicpw.sec", allow_pickle=True).item()
ind = 0
d = 0
guessed = []
for it in range(len(t)):
    for j in range(36):
        of = np.sum(np.abs(t[0][1][j][1]-t[0][0]))
        if of>d:
            d = of
            ind = it
    
    g = t[0][1][ind][0]
    guessed.append(g)

# %%
t[0][1][][0]
# Out:
# 'b\n'

# %%
# Out:
# 0

# %%
    for j in range(36):
        of = np.sum(np.abs(t[0][1][j][1]-t[0][0]))
        if of>d:
            d = of
            p = i
    
    g = t[0][1][p][0]
    print(of)
    print(g)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_94919/1153591482.py in <module>
#       6             p = i
#       7
# ----> 8     g = t[0][1][p][0]
#       9     print(of)
#      10     print(g)
#
# TypeError: unhashable type: 'numpy.ndarray'

# %%
guessed
# Out:
# []

# %%
import numpy as np
import matplotlib.pyplot as plt

trace = np.load('basicpw.sec', allow_pickle=True)

re_dict = trace.tolist()
# print('re_dict :', type(re_dict), re_dict)

#print the reference
ref = re_dict[0][0]
# print(ref)
plt.plot(ref)

p = 0 #index of the most probable character
max_diff = 0

#Compare the first character traces with the reference
for i in range(36):
  trc = re_dict[0][1][i][1]
  plt.plot(trc - ref)
  diff = np.sum(np.abs(trc - ref))
  
  #Save the max difference value and its index
  if diff > max_diff:
    max_diff = diff
    p = i

plt.show()

guess = re_dict[0][1][p][0]
print('Password guess: ' + guess + 'max difference: ', end = '')
print(max_diff)
print(diff)
# Out:
# Password guess: a
# max difference: 347.31640625
# 24.4853515625

# %%
m.tolist()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_94919/2505393369.py in <module>
# ----> 1 m.tolist()
#
# AttributeError: 'dict' object has no attribute 'tolist'
